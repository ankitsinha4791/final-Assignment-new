# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Jupiter Notebook on IBM Watson Studio

# %% [markdown]
# **Ankit Kumar Sinha** <br>
# Student pursuing B.tech in Computer Science engineering

# %% [markdown]
# *I am very much interested in Data Science because I want to learn the ways to deal with big data and also want to explore new ways in this field.*

# %% [markdown]
# ### My code will simply multiply two numbers

# %%
8*6
# Out:
# 48

# %% [markdown]
# ***

# %% [markdown]
# Some use of bulleted list <br>

# %% [markdown]
# - Accurate

# %% [markdown]
# - Large data analysation

# %% [markdown]
# Some use of numbered list <br> 1. Good<br> 2. Better

# %% [markdown]
# link to wikipedia __https://en.wikipedia.org/wiki/Data_science __

# %% [markdown]
# img src="https://en.wikipedia.org/wiki/Taj_Mahal#/media/File:Taj_Mahal_in_India_-_Kristian_Bertel.jpg />
